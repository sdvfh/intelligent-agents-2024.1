# %%
from Astar import Astar
from London.data_loader import DataLoader

# %%
astar = Astar("London\\real_distances.csv", "London\\straight_line_distances.csv")
# Out:
# e:\Mestrado\Introducao-agentes-inteligentes\Projeto-A-estrela\intelligent-agents-2024.1\London\data_loader\data_loader.py:30: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.real_dist_df = self.real_dist_df.replace('x', np.nan)

# %%
astar.calculate_A_star("E1", "E5")
# Out:
# Current frontier nodes: ['E2']
# selected node: E2 | f: 26.10 | h: 19.65 | g: 6.45 | path: ['E1']
# Current frontier nodes: ['E1', 'E3', 'E7', 'E9']
# selected node: E3 | f: 46.80 | h: 12.75 | g: 34.05 | path: ['E1', 'E2']
# Baldeação necessária para ir de E3 para E7, vindo de E2
# Baldeação necessária para ir de E3 para E8, vindo de E2
# Current frontier nodes: ['E1', 'E7', 'E9', 'E2', 'E4', 'E8']
# selected node: E9 | f: 50.55 | h: 18.00 | g: 32.55 | path: ['E1', 'E2']
# Current frontier nodes: ['E1', 'E7', 'E2', 'E4', 'E8', 'E9', 'E10']
# selected node: E1 | f: 58.35 | h: 25.80 | g: 32.55 | path: ['E1', 'E2']
# Current frontier nodes: ['E7', 'E2', 'E4', 'E8', 'E9', 'E10']
# selected node: E4 | f: 60.00 | h: 4.35 | g: 55.65 | path: ['E1', 'E2', 'E3']
# Baldeação necessária para ir de E4 para E5, vindo de E3
# Baldeação necessária para ir de E4 para E10, vindo de E3
# Current frontier nodes: ['E7', 'E2', 'E8', 'E9', 'E10', 'E3', 'E5', 'E14']
# selected node: E8 | f: 66.45 | h: 10.50 | g: 55.95 | path: ['E1', 'E2', 'E3']
# Baldeação necessária para ir de E8 para E4, vindo de E3
# Baldeação necessária para ir de E8 para E9, vindo de E3
# Current frontier nodes: ['E7', 'E2', 'E9', 'E10', 'E3', 'E5', 'E14', 'E4']
# selected node: E5 | f: 67.35 | h: 0.00 | g: 67.35 | path: ['E1', 'E2', 'E3', 'E4']
# Found goal node: E5 | path: ['E1', 'E2', 'E3', 'E4'] | f: 67.35 | h: 0.00 | g: 67.35

# %% [markdown]
# ### Visualizing Data

# %%
astar.neighbors_dict
# Out:
# {'E1': {'E2': 4.3},
#  'E2': {'E1': 4.3, 'E3': 5.3, 'E7': 14.3, 'E9': 4.3},
#  'E3': {'E2': 5.3, 'E4': 5.9, 'E7': 8.5, 'E8': 4.1},
#  'E4': {'E3': 5.9, 'E5': 2.9, 'E10': 4.0, 'E14': 6.2},
#  'E5': {'E4': 2.9},
#  'E6': {'E7': 3.2},
#  'E7': {'E2': 14.3, 'E3': 8.5, 'E5': 3.2},
#  'E8': {'E3': 4.1, 'E4': 4.0, 'E9': 5.0, 'E10': 6.0},
#  'E9': {'E2': 4.3, 'E7': 5.0, 'E9': 3.0, 'E10': 3.4},
#  'E10': {'E7': 6.0, 'E8': 3.0, 'E11': 5.6, 'E12': 9.1},
#  'E11': {'E7': 3.4},
#  'E12': {'E9': 5.6},
#  'E13': {'E9': 9.1},
#  'E14': {'E5': 6.2}}

# %%
for key in astar.straightline_distances:
    print(astar.straightline_distances[key])
# Out:
# {'E2': 4.3, 'E3': 9.0, 'E4': 14.7, 'E5': 17.2, 'E6': 13.1, 'E7': 11.8, 'E8': 11.3, 'E9': 8.2, 'E10': 10.7, 'E11': 8.4, 'E12': 14.1, 'E13': 18.5, 'E14': 17.3}
# {'E1': 4.3, 'E3': 5.3, 'E4': 10.3, 'E5': 13.1, 'E6': 12.7, 'E7': 10.3, 'E8': 6.9, 'E9': 4.3, 'E10': 7.4, 'E11': 5.9, 'E12': 11.3, 'E13': 14.8, 'E14': 12.9}
# {'E1': 9.0, 'E2': 5.3, 'E4': 5.9, 'E5': 8.5, 'E6': 10.9, 'E7': 7.7, 'E8': 4.1, 'E9': 6.5, 'E10': 8.9, 'E11': 9.4, 'E12': 14.5, 'E13': 13.9, 'E14': 10.3}
# {'E1': 14.7, 'E2': 10.3, 'E3': 5.9, 'E5': 2.9, 'E6': 15.0, 'E7': 12.7, 'E8': 4.0, 'E9': 9.1, 'E10': 9.7, 'E11': 12.2, 'E12': 14.7, 'E13': 10.6, 'E14': 6.0}
# {'E1': 17.2, 'E2': 13.1, 'E3': 8.5, 'E4': 2.9, 'E6': 16.0, 'E7': 12.3, 'E8': 7.0, 'E9': 12.0, 'E10': 15.3, 'E11': 14.8, 'E12': 17.3, 'E13': 12.7, 'E14': 6.9}
# {'E1': 13.1, 'E2': 12.7, 'E3': 10.9, 'E4': 15.0, 'E5': 16.0, 'E7': 3.2, 'E8': 15.1, 'E9': 16.5, 'E10': 18.5, 'E11': 19.0, 'E12': 24.3, 'E13': 25.2, 'E14': 21.1}
# {'E1': 11.8, 'E2': 10.3, 'E3': 7.7, 'E4': 12.7, 'E5': 12.3, 'E6': 3.2, 'E8': 12.0, 'E9': 13.3, 'E10': 16.4, 'E11': 16.0, 'E12': 22.2, 'E13': 22.6, 'E14': 17.1}
# {'E1': 11.3, 'E2': 6.9, 'E3': 4.1, 'E4': 4.0, 'E5': 7.0, 'E6': 15.1, 'E7': 12.0, 'E9': 5.0, 'E10': 5.6, 'E11': 7.9, 'E12': 12.4, 'E13': 9.8, 'E14': 6.4}
# {'E1': 8.2, 'E2': 4.3, 'E3': 6.5, 'E4': 9.1, 'E5': 12.0, 'E6': 16.5, 'E7': 13.3, 'E8': 5.0, 'E10': 3.0, 'E11': 3.4, 'E12': 8.1, 'E13': 10.9, 'E14': 9.6}
# {'E1': 10.7, 'E2': 7.4, 'E3': 8.9, 'E4': 9.7, 'E5': 15.3, 'E6': 18.5, 'E7': 16.4, 'E8': 5.6, 'E9': 3.0, 'E11': 3.4, 'E12': 5.6, 'E13': 7.7, 'E14': 8.4}
# {'E1': 8.4, 'E2': 5.9, 'E3': 9.4, 'E4': 12.2, 'E5': 14.8, 'E6': 19.0, 'E7': 16.0, 'E8': 7.9, 'E9': 3.4, 'E10': 3.4, 'E12': 5.9, 'E13': 11.2, 'E14': 12.7}
# {'E1': 14.1, 'E2': 11.3, 'E3': 14.5, 'E4': 14.7, 'E5': 17.3, 'E6': 24.3, 'E7': 22.2, 'E8': 12.4, 'E9': 8.1, 'E10': 5.6, 'E11': 5.9, 'E13': 8.6, 'E14': 12.3}
# {'E1': 18.5, 'E2': 14.8, 'E3': 13.9, 'E4': 10.6, 'E5': 12.7, 'E6': 25.2, 'E7': 22.6, 'E8': 9.8, 'E9': 10.9, 'E10': 7.7, 'E11': 11.2, 'E12': 8.6, 'E14': 6.1}
# {'E1': 17.3, 'E2': 12.9, 'E3': 10.3, 'E4': 6.0, 'E5': 6.9, 'E6': 21.1, 'E7': 17.1, 'E8': 6.4, 'E9': 9.6, 'E10': 8.4, 'E11': 12.7, 'E12': 12.3, 'E13': 6.1}

# %%
data_loader = DataLoader("London\\real_distances.csv", "London\\straight_line_distances.csv")

# %%
data_loader.real_dist_df
# Out:
#    node   E1    E2   E3   E4   E5   E6    E7   E8   E9  E10  E11  E12  E13  \
# 0    E1  NaN   4.3  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    E2  4.3   NaN  5.3  NaN  NaN  NaN  14.3  NaN  4.3  NaN  NaN  NaN  NaN
# 2    E3  NaN   5.3  NaN  5.9  NaN  NaN   8.5  4.1  NaN  NaN  NaN  NaN  NaN
# 3    E4  NaN   NaN  5.9  NaN  2.9  NaN   NaN    4  NaN  NaN  NaN  NaN  NaN
# 4    E5  NaN   NaN  NaN  2.9  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5    E6  NaN   NaN  NaN  NaN  NaN  NaN   3.2  NaN  NaN  NaN  NaN  NaN  NaN
# 6    E7  NaN  14.3  8.5  NaN  NaN  3.2   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7    E8  NaN   NaN  4.1    4  NaN  NaN   NaN  NaN    5    6  NaN  NaN  NaN
# 8    E9  NaN   4.3  NaN  NaN  NaN  NaN   NaN    5  NaN    3  3.4  NaN  NaN
# 9   E10  NaN   NaN  NaN  NaN  NaN  NaN   NaN    6    3  NaN  NaN  5.6  9.1
# 10  E11  NaN   NaN  NaN  NaN  NaN  NaN   NaN  NaN  3.4  NaN  NaN  NaN  NaN
# 11  E12  NaN   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  5.6  NaN  NaN  NaN
# 12  E13  NaN   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  9.1  NaN  NaN  NaN
# 13  E14  NaN   NaN  NaN  6.2  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     E14
# 0   NaN
# 1   NaN
# 2   NaN
# 3   6.2
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN

# %%
data_loader.straightline_dist_df
# Out:
#    node    E1    E2    E3    E4    E5    E6    E7    E8    E9   E10   E11  \
# 0    E1   NaN   4.3     9  14.7  17.2  13.1  11.8  11.3   8.2  10.7   8.4
# 1    E2   4.3   NaN   5.3  10.3  13.1  12.7  10.3   6.9   4.3   7.4   5.9
# 2    E3     9   5.3   NaN   5.9   8.5  10.9   7.7   4.1   6.5   8.9   9.4
# 3    E4  14.7  10.3   5.9   NaN   2.9    15  12.7     4   9.1   9.7  12.2
# 4    E5  17.2  13.1   8.5   2.9   NaN    16  12.3     7    12  15.3  14.8
# 5    E6  13.1  12.7  10.9    15    16   NaN   3.2  15.1  16.5  18.5    19
# 6    E7  11.8  10.3   7.7  12.7  12.3   3.2   NaN    12  13.3  16.4    16
# 7    E8  11.3   6.9   4.1     4     7  15.1    12   NaN     5   5.6   7.9
# 8    E9   8.2   4.3   6.5   9.1    12  16.5  13.3     5   NaN     3   3.4
# 9   E10  10.7   7.4   8.9   9.7  15.3  18.5  16.4   5.6     3   NaN   3.4
# 10  E11   8.4   5.9   9.4  12.2  14.8    19    16   7.9   3.4   3.4   NaN
# 11  E12  14.1  11.3  14.5  14.7  17.3  24.3  22.2  12.4   8.1   5.6   5.9
# 12  E13  18.5  14.8  13.9  10.6  12.7  25.2  22.6   9.8  10.9   7.7  11.2
# 13  E14  17.3  12.9  10.3     6   6.9  21.1  17.1   6.4   9.6   8.4  12.7
#
#      E12   E13   E14
# 0   14.1  18.5  17.3
# 1   11.3  14.8  12.9
# 2   14.5  13.9  10.3
# 3   14.7  10.6     6
# 4   17.3  12.7   6.9
# 5   24.3  25.2  21.1
# 6   22.2  22.6  17.1
# 7   12.4   9.8   6.4
# 8    8.1  10.9   9.6
# 9    5.6   7.7   8.4
# 10   5.9  11.2  12.7
# 11   NaN   8.6  12.3
# 12   8.6   NaN   6.1
# 13  12.3   6.1   NaN
